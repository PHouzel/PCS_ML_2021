# %%
# Ensure relevant packages are installed
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install biopython
# !{sys.executable} -m pip install keras
# !{sys.executable} -m pip install tensorflow
# !{sys.executable} -m pip install hyperopt
# Out:
# Requirement already satisfied: numpy in /home/marie/anaconda3/lib/python3.8/site-packages (1.20.1)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: scikit-learn in /home/marie/anaconda3/lib/python3.8/site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: joblib>=0.11 in /home/marie/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/marie/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.20.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/marie/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.6.2)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=6bcbc5c064a6c4f23edd858c628f179ca48892eea5521d42dda59f0f97c5509c
#   Stored in directory: /home/marie/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# Requirement already satisfied: biopython in /home/marie/anaconda3/lib/python3.8/site-packages (1.79)
# Requirement already satisfied: numpy in /home/marie/anaconda3/lib/python3.8/site-packages (from biopython) (1.20.1)
# Requirement already satisfied: keras in /home/marie/anaconda3/lib/python3.8/site-packages (2.7.0)
# Requirement already satisfied: tensorflow in /home/marie/anaconda3/lib/python3.8/site-packages (2.7.0)
# Requirement already satisfied: tensorboard~=2.6 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=0.4.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.23.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.43.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: numpy>=1.14.5 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.20.1)
# Requirement already satisfied: protobuf>=3.9.2 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/marie/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/marie/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/marie/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/marie/anaconda3/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.9.0)
# Requirement already satisfied: zipp>=0.5 in /home/marie/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/marie/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/marie/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/marie/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/marie/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/marie/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 963 kB/s eta 0:00:01
# Requirement already satisfied: networkx>=2.2 in /home/marie/anaconda3/lib/python3.8/site-packages (from hyperopt) (2.5)
# Requirement already satisfied: numpy in /home/marie/anaconda3/lib/python3.8/site-packages (from hyperopt) (1.20.1)
# Requirement already satisfied: cloudpickle in /home/marie/anaconda3/lib/python3.8/site-packages (from hyperopt) (1.6.0)
# Requirement already satisfied: six in /home/marie/anaconda3/lib/python3.8/site-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: future in /home/marie/anaconda3/lib/python3.8/site-packages (from hyperopt) (0.18.2)
# Requirement already satisfied: tqdm in /home/marie/anaconda3/lib/python3.8/site-packages (from hyperopt) (4.59.0)
# Requirement already satisfied: scipy in /home/marie/anaconda3/lib/python3.8/site-packages (from hyperopt) (1.6.2)
# Collecting py4j
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: decorator>=4.3.0 in /home/marie/anaconda3/lib/python3.8/site-packages (from networkx>=2.2->hyperopt) (5.0.6)
# Installing collected packages: py4j, hyperopt
# Successfully installed hyperopt-0.2.7 py4j-0.10.9.3

# %%
from Bio import SeqIO
import sys
import numpy as np
np.set_printoptions(threshold=sys.maxsize)

#Encode a single protein sequence into a vector with 96*20 = 1920 binary variables
def one_hot_encoder(MSA_str, alphabet):
    # define a mapping of characters to integers
    char_to_int = dict((c, i) for i, c in enumerate(alphabet))
    # integer encode input data
    integer_encoded = [char_to_int[char] for char in MSA_str]
    # one hot encode integers
    onehot_encoded = list()
    for value in integer_encoded:
        if value == char_to_int.get("-"):
            letter = [0 for value in range(len(alphabet)-1)]
        else:
            letter = [0 for value in range(len(alphabet)-1)]
            letter[value] = 1
        onehot_encoded.append(letter)
        
    #At this point, we have 96 vectors of 20 binary variables, one vector per letter
    #Concatenate them to have one vector of 1920 variables
    concatenated = onehot_encoded[0]
    for i in range(len(onehot_encoded)-1):
        concatenated = np.concatenate((concatenated, onehot_encoded[i+1]), axis = None)
        
    return concatenated

# %%
#One-hot encoder

def one_hot_encode(sequence):
    """
    Input : sequence "--ATCGQRT-W-" for instance
    Output : numpy array, one line = one amino acid hot-encoded (or gap -)
    """
    X_in_seq = "X" in sequence
    if X_in_seq == True :
        return "to_remove"
    else :
        m = np.eye(20) #identity matrix, 20 amino acids
        m = np.vstack([m, np.zeros(20)]) #add zero line for '-', same length as amino acids hot encoding
        mapping = dict(zip(("ACDEFGHIKLMNPQRSTVWY-"), range(21))) #mapping of the sequence to encode
        sequence_mapped = [mapping[i] for i in sequence] #mapped sequence ("ACDE-" --> [0,1,2,3,20])  
        return m[sequence_mapped].reshape(len(sequence)*20) #takes the line of 0&1s from m that corresponds to the mapping

#test 
#one_hot_encode("AD-")

# %%
#Use one_hot_encoder on all the elements in one file: end up with N vectors of 1920 variables
def read_and_encode(file, alphabet):
    
    #Store relevant data in dictionary
    #Keys: sequence_number; values: sequence, functionality (functional_true, functional_false)
    data_dict = {}
    index=1
    #name sequences as "sequence_#": do this in roundabout way since third file does not name thep thus
    for seq_record in SeqIO.parse(file, "fasta"):
        data_dict['sequence_' + str(index)] = seq_record.seq
        index += 1
        data_dict[seq_record.id] = seq_record.seq, seq_record.description.replace(seq_record.id+' ','',1)
    
    #Array one: one vector per string => [N, 20*92]
    encoded_data = np.empty([len(data_dict), (len(alphabet)-1)*(len(data_dict['sequence_1'][0]))])
    #Array 2: one binary label per string => [N]
    labels = np.empty(len(data_dict))
    
    #Encode every sequence in the file
    for i in range(len(data_dict)):
        sequence = data_dict.get("sequence_"+str(i+1))[0] #this [0] makes the function crash for the unlabeled file
        encoded_data[i] = one_hot_encoder(sequence, alphabet)
        
        #if functional_true => encode 1 in labels
        if data_dict.get("sequence_"+str(i+1))[1] == "functional_true":
            labels[i]=1
        #if functional_false => encode 0 in labels
        elif data_dict.get("sequence_"+str(i+1))[1] == "functional_false":
            labels[i]=0
      
    return encoded_data, labels

#Slightly different for unlabelled data
def read_and_encode_unlab(file, alphabet):
    data_dict = {}
    index=1
    for seq_record in SeqIO.parse(file, "fasta"):
        data_dict['sequence_' + str(index)] = seq_record.seq
        index += 1

    encoded_data_unlab = np.empty([len(data_dict), 1920])
    number_of_corrupted_lines = 0
    corrupted_indexes = []

    for i in range(len(data_dict)):
        sequence = data_dict.get("sequence_"+str(i+1))
        #Some Xs are hanging around in the files, need to avoid them
        try:
            encoded_data_unlab[i] = one_hot_encoder(sequence, alphabet)
        except:
            corrupted_indexes.append(i)
            number_of_corrupted_lines += 1

    print("The number of corrupted sequences is "+ str(number_of_corrupted_lines))

    for i in range(len(corrupted_indexes)):
        encoded_data_unlab = np.delete(encoded_data_unlab, i, axis = 0)
    return encoded_data_unlab

# %%
#Read files
#Check that everything works
alphabet ='ACDEFGHIKLMNPQRSTVWY-' #the alphabet we'll use the whole time

encoded_data_nat, labels_nat = read_and_encode("./MSA_nat_with_annotation.faa", alphabet)
print("The shapes of the oneshot encoded natural data and of the label files are " + str(np.shape(encoded_data_nat)) + " and " + str(np.shape(labels_nat))+" respectively")

encoded_data_art, labels_art = read_and_encode("./MSA_art.faa", alphabet)
print("The shapes of the oneshot encoded artificial data and of the label files are " + str(np.shape(encoded_data_art)) + " and " + str(np.shape(labels_art))+" respectively")

all_lab_data = np.concatenate((encoded_data_art, encoded_data_nat))
all_lab = np.concatenate((labels_nat, labels_art))
print("The shapes of all the oneshot encoded labeled data and of their label file are " + str(np.shape(all_lab_data)) + " and " + str(np.shape(all_lab))+" respectively")

encoded_data_unlab = read_and_encode_unlab("./MSA_nat_no_annotation.faa", alphabet)
print("The shape of the oneshot encoded unlabeled data is " + str(np.shape(encoded_data_unlab)))
# Out:
# The shapes of the oneshot encoded natural data and of the label files are (1130, 1920) and (1130,) respectively
# The shapes of the oneshot encoded artificial data and of the label files are (1003, 1920) and (1003,) respectively
# The shapes of all the oneshot encoded labeled data and of their label file are (2133, 1920) and (2133,) respectively
# The number of corrupted sequences is 42
# The shape of the oneshot encoded unlabeled data is (6269, 1920)

# %%
from Bio import SeqIO
import sys
import numpy as np

encoded_data_art = [one_hot_encode(entry.seq) for entry in SeqIO.parse("MSA_art.faa", "fasta")] #artificial sequences
encoded_data_unlab = [one_hot_encode(entry.seq) for entry in SeqIO.parse("MSA_nat_no_annotation.faa", "fasta")]#natural without annotation
encoded_data_nat = [one_hot_encode(entry.seq) for entry in SeqIO.parse("MSA_nat_with_annotation.faa", "fasta")] #natural
encoded_data_unlab = [item for item in encoded_data_unlab if item != "to_remove"]

#full_data = art + nat_no + nat_yes
#annot_data = art + nat_yes
all_lab_data = np.concatenate((encoded_data_art,encoded_data_nat))

# %%
labels_nat = [1 if "true" in entry.description else 0 for entry in SeqIO.parse("MSA_nat_with_annotation.faa", "fasta")]
labels_art = [1 if "true" in entry.description else 0 for entry in SeqIO.parse("MSA_art.faa", "fasta")]

#func_annot_data = func_art + func_nat_yes
all_lab = np.concatenate((labels_art, labels_nat))

# %%
#Exercice 2: apply PCA
from sklearn.decomposition import PCA
import matplotlib
import matplotlib.pyplot as plt

#Standardizing the features: not needed - data is already scaled. But if we did:
#from sklearn.preprocessing import StandardScaler
#encoded_data = StandardScaler().fit_transform(encoded_data)
def apply_PCA(encoded_data):

    #Find number of components such that we keep, say, 95% of the variance when applying
    pca_test = PCA().fit(encoded_data)
    n_components= np.where(np.cumsum(pca_test.explained_variance_ratio_) > 0.95)
    min_n = n_components[0][0]
    print("With " + str(min_n) + " components, we keep 95% of the variance!")
    
    fig = plt.figure(figsize=(8,8))
    plt.plot(np.cumsum(pca_test.explained_variance_ratio_))
    plt.axvline(x=min_n, color='red', linestyle='--')
    plt.xlabel("number of components")
    plt.ylabel("cumulative explained variance")

    
    #Apply PCA with this optimal n
    pca = PCA(n_components=min_n)
    pcs_nat = pca.fit_transform(encoded_data_nat)
    principalComponents = pca.transform(encoded_data)

    two_compo_var = (pca.explained_variance_ratio_[0] + pca.explained_variance_ratio_[1])*100
    print("With the first 2 components, we only keep " + str(two_compo_var) + "% of the variance")
    
    return principalComponents

#Visualize the first two principle components
def visualize_pcs(principalComponents, labels, title):
    #red => 0 => functional_false; green => 1 => functional_true
    if(labels is None):
        colors = []
    else:
        colors = ['red','green']
        
    fig = plt.figure(figsize=(8,8))
    plt.scatter(principalComponents[:,0], principalComponents[:,1], c=labels, marker = '+', 
                cmap=matplotlib.colors.ListedColormap(colors))
    plt.xlabel('Principal Component - 1',fontsize=20)
    plt.ylabel('Principal Component - 2',fontsize=20)
    plt.title(title ,fontsize=20)

# %%
#Try this way, but we'll do it like above I guess
print("We have " + str(np.shape(encoded_data_nat)[0]) + " natural labelled sequences")
pcs_nat = apply_PCA(encoded_data_nat)
visualize_pcs(pcs_nat, labels_nat, "Principal Component Analysis of natural data")

print("We have " + str(np.shape(encoded_data_art)[0]) + " artificial labelled sequences")
pcs_art = apply_PCA(encoded_data_art)
visualize_pcs(pcs_art, labels_art, "Principal Component Analysis of artificial data")

print("We have " + str(np.shape(all_lab_data)[0]) + " labelled sequences")
pcs_all = apply_PCA(all_lab_data)
visualize_pcs(pcs_all, all_lab, "Principal Component Analysis of all labelled data")

print("We have " + str(np.shape(encoded_data_unlab)[0]) + " unlabelled sequences")
pcs_unlab = apply_PCA(encoded_data_unlab)
visualize_pcs(pcs_unlab, None, "Principal Component Analysis of all labelled data")
# Out:
# We have 1130 natural labelled sequences
# With 501 components, we keep 95% of the variance!
# With the first 2 components, we only keep 7.638790852685815% of the variance
# We have 1003 artificial labelled sequences
# With 312 components, we keep 95% of the variance!
# With the first 2 components, we only keep 7.638790852685825% of the variance
# We have 2133 labelled sequences
# With 529 components, we keep 95% of the variance!
# With the first 2 components, we only keep 7.638790852685837% of the variance
# We have 6269 unlabelled sequences
# With 512 components, we keep 95% of the variance!
# With the first 2 components, we only keep 7.638790852685819% of the variance

# %%
#We'll use 500
modelPCA = PCA(n_components=500)

nat_pcs = modelPCA.fit_transform(encoded_data_nat)
art_pcs = modelPCA.fit_transform(encoded_data_art)
all_pcs = modelPCA.fit_transform(all_lab_data)
unlab_pcs = modelPCA.fit_transform(encoded_data_unlab)

visualize_pcs(nat_pcs, labels_nat, "Principal Component Analysis of natural data")
visualize_pcs(art_pcs, labels_art, "Principal Component Analysis of artificial data")
visualize_pcs(all_pcs, all_lab, "Principal Component Analysis of all labelled data")
visualize_pcs(np.concatenate((nat_pcs, art_pcs)), np.concatenate((labels_nat, labels_art)), "Principal Component Analysis of all labelled data")
visualize_pcs(unlab_pcs, None, "Principal Component Analysis of all unlabelled data")

# %%
#Exercice 3: clustering

from sklearn.cluster import AgglomerativeClustering

def compo_cluster(data, pcs, title, n):

    method = AgglomerativeClustering(n_clusters = n)
    clustered = method.fit(data)
    labels = clustered.labels_
    colors = ['red','green']

    fig = plt.figure(figsize=(8,8))
    plt.scatter(pcs[:,0], pcs[:,1], c=labels, marker = '+')
            #cmap=matplotlib.colors.ListedColormap(colors))
    plt.xlabel('Principal Component - 1',fontsize=20)
    plt.ylabel('Principal Component - 2',fontsize=20)
    plt.title(title)

# %%
for i in range(8):
    compo_cluster(encoded_data_nat, pcs_nat, "Natural sequences " + str(i+2) + " clusters", i+2)
    compo_cluster(encoded_data_art, pcs_art, "Artificial sequences " + str(i+2) + " clusters", i+2)

#compo_cluster(encoded_data_unlab, pcs_unlab, "Unlabeled sequences", 2)

# %%
#Supervised learning: NN
import random
from keras import losses, optimizers, metrics, callbacks
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Input, Dense, Add, Dropout
                
params = {
        # https://keras.io/guides/sequential_model/
    'hidden_layers': {
            'units': 64,
            'activation': 'relu',
            'use_bias': True,
            'kernel_initializer': 'GlorotUniform',
            'kernel_regularizer': None,
            'bias_regularizer': 'l2',
            'activity_regularizer': None,
            'kernel_constraint': None,
            'bias_constraint': None
            },
    'compilation': {
            'optimizer': Adam(
                learning_rate=0.001
                ),
            'loss': losses.MeanSquaredError(),
            'metrics': [metrics.MeanSquaredError(), metrics.MeanAbsoluteError()],
        },
    'fit': {
        'batch_size': 32,
        'epochs': 100,
        'callbacks' : [
            callbacks.EarlyStopping(monitor='loss', patience=7), 
            callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)]
            }
          }

#Need to shuffle the data
input_data = all_pcs
#input_data = all_pcs
output_data = all_lab

print(np.shape(input_data))
# Steps to shuffle:
joined_lists = list(zip(input_data, output_data))
random.shuffle(joined_lists) # Shuffle "joined_lists" in place
input_data, output_data = zip(*joined_lists) # Undo joining
input_data = np.array(input_data)
output_data = np.array(output_data)
print(np.shape(input_data))

def create_DNN(input_data, hidden_layers_params, dropout_rate):
    model = Sequential() 
    input_layer = Dense(32, input_shape=(np.shape(input_data)[1],)) 
    model.add(input_layer) 
    hidden_layer = Dense(**hidden_layers_params)
    model.add(hidden_layer)
    dropout_layer = Dropout(dropout_rate)
    model.add(dropout_layer)
    hidden_layer = Dense(**hidden_layers_params)
    model.add(hidden_layer) 
    output_layer = Dense(1, activation='sigmoid') 
    model.add(output_layer)
    
    return model

#Set up network
model = create_DNN(all_pcs, params['hidden_layers'], dropout_rate=0.25)
model.compile(**params['compilation'])
# Out:
# (2133, 500)
# (2133, 500)

# %%
#Def fraction train/test/validation
fraction_train = 0.8
fraction_test = 0.1

stop_1 = int(fraction_train*len(output_data))
stop_2 = stop_1 + int(fraction_test*len(output_data))

X_train, Y_train = input_data[:stop_1], output_data[:stop_1]
X_test, Y_test = input_data[stop_1+1:stop_2], output_data[stop_1+1:stop_2]
X_validation, Y_validation = input_data[stop_2+1:], output_data[stop_2+1:]

print('Training network (this might take a while)...')
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_validation, Y_validation),
    verbose=1,
    **params['fit']
)
# Out:
# Training network (this might take a while)...
# Epoch 1/100
# 54/54 [==============================] - 1s 4ms/step - loss: 0.2206 - mean_squared_error: 0.2205 - mean_absolute_error: 0.4540 - val_loss: 0.1792 - val_mean_squared_error: 0.1790 - val_mean_absolute_error: 0.4005 - lr: 0.0010
# Epoch 2/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1461 - mean_squared_error: 0.1458 - mean_absolute_error: 0.3267 - val_loss: 0.1427 - val_mean_squared_error: 0.1423 - val_mean_absolute_error: 0.2985 - lr: 0.0010
# Epoch 3/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1070 - mean_squared_error: 0.1066 - mean_absolute_error: 0.2365 - val_loss: 0.1430 - val_mean_squared_error: 0.1426 - val_mean_absolute_error: 0.2650 - lr: 0.0010
# Epoch 4/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0900 - mean_squared_error: 0.0896 - mean_absolute_error: 0.1956 - val_loss: 0.1428 - val_mean_squared_error: 0.1425 - val_mean_absolute_error: 0.2482 - lr: 0.0010
# Epoch 5/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0747 - mean_squared_error: 0.0743 - mean_absolute_error: 0.1634 - val_loss: 0.1467 - val_mean_squared_error: 0.1464 - val_mean_absolute_error: 0.2380 - lr: 0.0010
# Epoch 6/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0652 - mean_squared_error: 0.0650 - mean_absolute_error: 0.1427 - val_loss: 0.1501 - val_mean_squared_error: 0.1498 - val_mean_absolute_error: 0.2281 - lr: 0.0010
# Epoch 7/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0571 - mean_squared_error: 0.0569 - mean_absolute_error: 0.1243 - val_loss: 0.1543 - val_mean_squared_error: 0.1540 - val_mean_absolute_error: 0.2287 - lr: 0.0010
# Epoch 8/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0501 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1097 - val_loss: 0.1488 - val_mean_squared_error: 0.1486 - val_mean_absolute_error: 0.2118 - lr: 0.0010
# Epoch 9/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0481 - mean_squared_error: 0.0479 - mean_absolute_error: 0.1017 - val_loss: 0.1598 - val_mean_squared_error: 0.1596 - val_mean_absolute_error: 0.2217 - lr: 0.0010
# Epoch 10/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0404 - mean_squared_error: 0.0403 - mean_absolute_error: 0.0879 - val_loss: 0.1591 - val_mean_squared_error: 0.1590 - val_mean_absolute_error: 0.2133 - lr: 0.0010
# Epoch 11/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0364 - mean_squared_error: 0.0362 - mean_absolute_error: 0.0788 - val_loss: 0.1541 - val_mean_squared_error: 0.1540 - val_mean_absolute_error: 0.2072 - lr: 0.0010
# Epoch 12/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0343 - mean_squared_error: 0.0342 - mean_absolute_error: 0.0714 - val_loss: 0.1583 - val_mean_squared_error: 0.1582 - val_mean_absolute_error: 0.2094 - lr: 0.0010
# Epoch 13/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0273 - mean_squared_error: 0.0272 - mean_absolute_error: 0.0606 - val_loss: 0.1604 - val_mean_squared_error: 0.1603 - val_mean_absolute_error: 0.2098 - lr: 1.0000e-04
# Epoch 14/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0270 - mean_squared_error: 0.0269 - mean_absolute_error: 0.0602 - val_loss: 0.1606 - val_mean_squared_error: 0.1604 - val_mean_absolute_error: 0.2095 - lr: 1.0000e-04
# Epoch 15/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0245 - mean_squared_error: 0.0244 - mean_absolute_error: 0.0551 - val_loss: 0.1606 - val_mean_squared_error: 0.1605 - val_mean_absolute_error: 0.2093 - lr: 1.0000e-04
# Epoch 16/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0244 - mean_squared_error: 0.0242 - mean_absolute_error: 0.0549 - val_loss: 0.1616 - val_mean_squared_error: 0.1615 - val_mean_absolute_error: 0.2091 - lr: 1.0000e-04
# Epoch 17/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0240 - mean_squared_error: 0.0239 - mean_absolute_error: 0.0547 - val_loss: 0.1621 - val_mean_squared_error: 0.1620 - val_mean_absolute_error: 0.2093 - lr: 1.0000e-04
# Epoch 18/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0234 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0526 - val_loss: 0.1623 - val_mean_squared_error: 0.1622 - val_mean_absolute_error: 0.2097 - lr: 1.0000e-04
# Epoch 19/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0229 - mean_squared_error: 0.0228 - mean_absolute_error: 0.0509 - val_loss: 0.1637 - val_mean_squared_error: 0.1636 - val_mean_absolute_error: 0.2100 - lr: 1.0000e-04
# Epoch 20/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0231 - mean_squared_error: 0.0229 - mean_absolute_error: 0.0520 - val_loss: 0.1633 - val_mean_squared_error: 0.1632 - val_mean_absolute_error: 0.2092 - lr: 1.0000e-04
# Epoch 21/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0225 - mean_squared_error: 0.0224 - mean_absolute_error: 0.0489 - val_loss: 0.1631 - val_mean_squared_error: 0.1630 - val_mean_absolute_error: 0.2091 - lr: 1.0000e-04
# Epoch 22/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0233 - mean_squared_error: 0.0232 - mean_absolute_error: 0.0504 - val_loss: 0.1632 - val_mean_squared_error: 0.1631 - val_mean_absolute_error: 0.2085 - lr: 1.0000e-04
# Epoch 23/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0223 - mean_squared_error: 0.0222 - mean_absolute_error: 0.0498 - val_loss: 0.1632 - val_mean_squared_error: 0.1631 - val_mean_absolute_error: 0.2084 - lr: 1.0000e-05
# Epoch 24/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0215 - mean_squared_error: 0.0214 - mean_absolute_error: 0.0491 - val_loss: 0.1632 - val_mean_squared_error: 0.1631 - val_mean_absolute_error: 0.2084 - lr: 1.0000e-05
# Epoch 25/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0219 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0487 - val_loss: 0.1634 - val_mean_squared_error: 0.1633 - val_mean_absolute_error: 0.2084 - lr: 1.0000e-05
# Epoch 26/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0226 - mean_squared_error: 0.0225 - mean_absolute_error: 0.0497 - val_loss: 0.1635 - val_mean_squared_error: 0.1634 - val_mean_absolute_error: 0.2085 - lr: 1.0000e-05
# Epoch 27/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0218 - mean_squared_error: 0.0217 - mean_absolute_error: 0.0484 - val_loss: 0.1634 - val_mean_squared_error: 0.1633 - val_mean_absolute_error: 0.2083 - lr: 1.0000e-05
# Epoch 28/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0231 - mean_squared_error: 0.0230 - mean_absolute_error: 0.0507 - val_loss: 0.1634 - val_mean_squared_error: 0.1633 - val_mean_absolute_error: 0.2082 - lr: 1.0000e-05
# Epoch 29/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0209 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0465 - val_loss: 0.1635 - val_mean_squared_error: 0.1634 - val_mean_absolute_error: 0.2082 - lr: 1.0000e-05
# Epoch 30/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0216 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0478 - val_loss: 0.1635 - val_mean_squared_error: 0.1634 - val_mean_absolute_error: 0.2082 - lr: 1.0000e-05
# Epoch 31/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0228 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0492 - val_loss: 0.1633 - val_mean_squared_error: 0.1632 - val_mean_absolute_error: 0.2079 - lr: 1.0000e-05
# Epoch 32/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0218 - mean_squared_error: 0.0217 - mean_absolute_error: 0.0475 - val_loss: 0.1634 - val_mean_squared_error: 0.1633 - val_mean_absolute_error: 0.2079 - lr: 1.0000e-05
# Epoch 33/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0212 - mean_squared_error: 0.0211 - mean_absolute_error: 0.0476 - val_loss: 0.1634 - val_mean_squared_error: 0.1633 - val_mean_absolute_error: 0.2079 - lr: 1.0000e-06
# Epoch 34/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0223 - mean_squared_error: 0.0222 - mean_absolute_error: 0.0487 - val_loss: 0.1634 - val_mean_squared_error: 0.1633 - val_mean_absolute_error: 0.2079 - lr: 1.0000e-06
# Epoch 35/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0216 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0470 - val_loss: 0.1634 - val_mean_squared_error: 0.1633 - val_mean_absolute_error: 0.2079 - lr: 1.0000e-06
# Epoch 36/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0216 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0476 - val_loss: 0.1634 - val_mean_squared_error: 0.1633 - val_mean_absolute_error: 0.2079 - lr: 1.0000e-06

# %%
print('Number of epochs run:', len(history.history['loss']))

# Calculate and print scores
print('Evaluating model performance on test set...')
scores = model.evaluate(X_test, Y_test, verbose=0)

max_metrics_name_length = len(max(model.metrics_names, key=len))
print()
print(' Scores '.center(max_metrics_name_length + 13, '='))
line = '{:<%i} : {:.4e}' % max_metrics_name_length
for i in range(len(model.metrics_names)):
    print(line.format(model.metrics_names[i], scores[i]))
print()
# Out:
# Number of epochs run: 36
# Evaluating model performance on test set...
#
# ============ Scores ============
# loss                : 1.7243e-01
# mean_squared_error  : 1.7233e-01
# mean_absolute_error : 2.1818e-01

# %%
# print performance
print()
print('Test loss:', scores[0])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
# Out:
# Test loss: 0.17242759466171265

# %%
#That's bad, so we'll try to optimize those parameters with a grid search
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from tensorflow.keras.optimizers import SGD, Adam

space={'learning_rate': hp.choice('learning_rate', [0.1, 1, 2, 3]),
       'dropout_rate': hp.choice('dropout_rate', [0., 0.1, 0.25, 0.4]),
       'units': hp.choice('units', [10, 20, 32, 64])
       #'momentum': hp.choice('momentum', [0.001, 0.1, 1])
       #'batch_size': hp.choice('batch_size', [16, 32, 48, 64]),
       #'patience_1': hp.choice('patience_1', [3, 5, 7, 10]),
       #'patience_2': hp.choice('patience_2', [3, 5, 7, 10])
    #'optimizer': hp.choice('optimizer', ['SGD','Adam'])
}

def objective(target):
    
    params = {
        # https://keras.io/guides/sequential_model/
    'hidden_layers': {
            'units': 64,
            'activation': 'relu',
            'use_bias': True,
            'kernel_initializer': 'GlorotUniform',
            'kernel_regularizer': None,
            'bias_regularizer': 'l2',
            'activity_regularizer': None,
            'kernel_constraint': None,
            'bias_constraint': None
            },
    'dropout_rate': 0.25,
    'compilation': {
            'optimizer': SGD(
                learning_rate=0.001,
                momentum=0.1
                ),
            'loss': losses.MeanSquaredError(),
            'metrics': [metrics.MeanSquaredError(), metrics.MeanAbsoluteError()],
            #'momentum': 0.
        },
    'fit': {
        'batch_size': 48,
        'epochs': 100,
        'callbacks' : [
            callbacks.EarlyStopping(monitor='loss', patience=10), 
            callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)]
            }
          }

    # Create model and train it
    model = create_DNN(all_pcs, params['hidden_layers'], dropout_rate=0.25)
    model.compile(**params['compilation'])
    history = model.fit(
        X_train,
        Y_train,
        validation_data=(X_validation, Y_validation),
        verbose=0,
        **params['fit']
        )
    
    loss=history.history['val_loss'][-1]
    
    return {'loss': loss, 'status': STATUS_OK }

trials=Trials()
best = fmin(objective,
            space, 
            algo=tpe.suggest, 
            trials=trials, 
            max_evals=100
            )

print ("Best result:", best)
print (trials.best_trial)
# Out:
# 100%|██████████| 100/100 [03:24<00:00,  2.04s/trial, best loss: 0.22954416275024414]
# Best result: {'dropout_rate': 2, 'learning_rate': 1, 'units': 1}
# {'state': 2, 'tid': 92, 'spec': None, 'result': {'loss': 0.22954416275024414, 'status': 'ok'}, 'misc': {'tid': 92, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout_rate': [92], 'learning_rate': [92], 'units': [92]}, 'vals': {'dropout_rate': [2], 'learning_rate': [1], 'units': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2022, 1, 23, 12, 0, 52, 824000), 'refresh_time': datetime.datetime(2022, 1, 23, 12, 0, 54, 932000)}

# %%
#Now retrain the network with those optimal parameters
params = {
        # https://keras.io/guides/sequential_model/
    'hidden_layers': {
            'units': 64,
            'activation': 'relu',
            'use_bias': True,
            'kernel_initializer': 'GlorotUniform',
            'kernel_regularizer': None,
            'bias_regularizer': 'l2',
            'activity_regularizer': None,
            'kernel_constraint': None,
            'bias_constraint': None
            },
    'dropout_rate': 0.25,
    'compilation': {
            'optimizer': SGD(
                learning_rate=0.001,
                momentum=0.1
                ),
            'loss': losses.MeanSquaredError(),
            'metrics': [metrics.MeanSquaredError(), metrics.MeanAbsoluteError()],
            #'momentum': 0.
        },
    'fit': {
        'batch_size': 48,
        'epochs': 100,
        'callbacks' : [
            callbacks.EarlyStopping(monitor='loss', patience=7), 
            callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)]
            }
          }

#Set up network
model = create_DNN(all_pcs, params['hidden_layers'], params['dropout_rate'])
model.compile(**params['compilation'])
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_validation, Y_validation),
    verbose=1,
    **params['fit']
)

print('Number of epochs run:', len(history.history['loss']))

# Calculate and print scores
print('Evaluating model performance on test set...')
scores = model.evaluate(X_test, Y_test, verbose=0)

max_metrics_name_length = len(max(model.metrics_names, key=len))
print()
print(' Scores '.center(max_metrics_name_length + 13, '='))
line = '{:<%i} : {:.4e}' % max_metrics_name_length
for i in range(len(model.metrics_names)):
    print(line.format(model.metrics_names[i], scores[i]))
print()

# print performance
print()
print('Test loss:', scores[0])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
# Out:
# Epoch 1/100
# 36/36 [==============================] - 1s 4ms/step - loss: 0.2533 - mean_squared_error: 0.2533 - mean_absolute_error: 0.4995 - val_loss: 0.2488 - val_mean_squared_error: 0.2488 - val_mean_absolute_error: 0.4966 - lr: 0.0010
# Epoch 2/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2494 - mean_squared_error: 0.2494 - mean_absolute_error: 0.4954 - val_loss: 0.2481 - val_mean_squared_error: 0.2481 - val_mean_absolute_error: 0.4959 - lr: 0.0010
# Epoch 3/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2514 - mean_squared_error: 0.2514 - mean_absolute_error: 0.4976 - val_loss: 0.2474 - val_mean_squared_error: 0.2474 - val_mean_absolute_error: 0.4952 - lr: 0.0010
# Epoch 4/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2496 - mean_squared_error: 0.2496 - mean_absolute_error: 0.4955 - val_loss: 0.2468 - val_mean_squared_error: 0.2468 - val_mean_absolute_error: 0.4945 - lr: 0.0010
# Epoch 5/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2484 - mean_squared_error: 0.2484 - mean_absolute_error: 0.4945 - val_loss: 0.2461 - val_mean_squared_error: 0.2461 - val_mean_absolute_error: 0.4938 - lr: 0.0010
# Epoch 6/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2497 - mean_squared_error: 0.2497 - mean_absolute_error: 0.4961 - val_loss: 0.2454 - val_mean_squared_error: 0.2454 - val_mean_absolute_error: 0.4931 - lr: 0.0010
# Epoch 7/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2473 - mean_squared_error: 0.2473 - mean_absolute_error: 0.4934 - val_loss: 0.2448 - val_mean_squared_error: 0.2448 - val_mean_absolute_error: 0.4925 - lr: 0.0010
# Epoch 8/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2465 - mean_squared_error: 0.2465 - mean_absolute_error: 0.4926 - val_loss: 0.2442 - val_mean_squared_error: 0.2442 - val_mean_absolute_error: 0.4918 - lr: 0.0010
# Epoch 9/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2460 - mean_squared_error: 0.2460 - mean_absolute_error: 0.4921 - val_loss: 0.2436 - val_mean_squared_error: 0.2436 - val_mean_absolute_error: 0.4911 - lr: 0.0010
# Epoch 10/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2454 - mean_squared_error: 0.2454 - mean_absolute_error: 0.4916 - val_loss: 0.2430 - val_mean_squared_error: 0.2430 - val_mean_absolute_error: 0.4905 - lr: 0.0010
# Epoch 11/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2455 - mean_squared_error: 0.2455 - mean_absolute_error: 0.4917 - val_loss: 0.2424 - val_mean_squared_error: 0.2424 - val_mean_absolute_error: 0.4899 - lr: 0.0010
# Epoch 12/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2447 - mean_squared_error: 0.2447 - mean_absolute_error: 0.4908 - val_loss: 0.2418 - val_mean_squared_error: 0.2418 - val_mean_absolute_error: 0.4892 - lr: 0.0010
# Epoch 13/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2430 - mean_squared_error: 0.2430 - mean_absolute_error: 0.4892 - val_loss: 0.2412 - val_mean_squared_error: 0.2412 - val_mean_absolute_error: 0.4886 - lr: 0.0010
# Epoch 14/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2434 - mean_squared_error: 0.2434 - mean_absolute_error: 0.4893 - val_loss: 0.2406 - val_mean_squared_error: 0.2406 - val_mean_absolute_error: 0.4880 - lr: 0.0010
# Epoch 15/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2435 - mean_squared_error: 0.2435 - mean_absolute_error: 0.4893 - val_loss: 0.2401 - val_mean_squared_error: 0.2401 - val_mean_absolute_error: 0.4873 - lr: 0.0010
# Epoch 16/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2417 - mean_squared_error: 0.2416 - mean_absolute_error: 0.4874 - val_loss: 0.2395 - val_mean_squared_error: 0.2395 - val_mean_absolute_error: 0.4867 - lr: 0.0010
# Epoch 17/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2428 - mean_squared_error: 0.2428 - mean_absolute_error: 0.4884 - val_loss: 0.2390 - val_mean_squared_error: 0.2390 - val_mean_absolute_error: 0.4861 - lr: 0.0010
# Epoch 18/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2419 - mean_squared_error: 0.2419 - mean_absolute_error: 0.4878 - val_loss: 0.2385 - val_mean_squared_error: 0.2385 - val_mean_absolute_error: 0.4855 - lr: 0.0010
# Epoch 19/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2414 - mean_squared_error: 0.2414 - mean_absolute_error: 0.4871 - val_loss: 0.2379 - val_mean_squared_error: 0.2379 - val_mean_absolute_error: 0.4849 - lr: 0.0010
# Epoch 20/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2398 - mean_squared_error: 0.2398 - mean_absolute_error: 0.4855 - val_loss: 0.2374 - val_mean_squared_error: 0.2374 - val_mean_absolute_error: 0.4843 - lr: 0.0010
# Epoch 21/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2378 - mean_squared_error: 0.2378 - mean_absolute_error: 0.4832 - val_loss: 0.2369 - val_mean_squared_error: 0.2369 - val_mean_absolute_error: 0.4837 - lr: 0.0010
# Epoch 22/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2384 - mean_squared_error: 0.2384 - mean_absolute_error: 0.4836 - val_loss: 0.2364 - val_mean_squared_error: 0.2364 - val_mean_absolute_error: 0.4831 - lr: 0.0010
# Epoch 23/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2394 - mean_squared_error: 0.2394 - mean_absolute_error: 0.4848 - val_loss: 0.2359 - val_mean_squared_error: 0.2359 - val_mean_absolute_error: 0.4825 - lr: 0.0010
# Epoch 24/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2369 - mean_squared_error: 0.2369 - mean_absolute_error: 0.4821 - val_loss: 0.2354 - val_mean_squared_error: 0.2354 - val_mean_absolute_error: 0.4819 - lr: 0.0010
# Epoch 25/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2376 - mean_squared_error: 0.2376 - mean_absolute_error: 0.4827 - val_loss: 0.2349 - val_mean_squared_error: 0.2349 - val_mean_absolute_error: 0.4813 - lr: 0.0010
# Epoch 26/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2366 - mean_squared_error: 0.2366 - mean_absolute_error: 0.4817 - val_loss: 0.2344 - val_mean_squared_error: 0.2344 - val_mean_absolute_error: 0.4807 - lr: 0.0010
# Epoch 27/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2354 - mean_squared_error: 0.2354 - mean_absolute_error: 0.4802 - val_loss: 0.2339 - val_mean_squared_error: 0.2339 - val_mean_absolute_error: 0.4801 - lr: 0.0010
# Epoch 28/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2360 - mean_squared_error: 0.2360 - mean_absolute_error: 0.4809 - val_loss: 0.2334 - val_mean_squared_error: 0.2334 - val_mean_absolute_error: 0.4795 - lr: 0.0010
# Epoch 29/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2354 - mean_squared_error: 0.2353 - mean_absolute_error: 0.4802 - val_loss: 0.2330 - val_mean_squared_error: 0.2330 - val_mean_absolute_error: 0.4789 - lr: 0.0010
# Epoch 30/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2330 - mean_squared_error: 0.2329 - mean_absolute_error: 0.4777 - val_loss: 0.2325 - val_mean_squared_error: 0.2325 - val_mean_absolute_error: 0.4784 - lr: 0.0010
# Epoch 31/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2347 - mean_squared_error: 0.2347 - mean_absolute_error: 0.4793 - val_loss: 0.2320 - val_mean_squared_error: 0.2320 - val_mean_absolute_error: 0.4778 - lr: 0.0010
# Epoch 32/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2338 - mean_squared_error: 0.2338 - mean_absolute_error: 0.4784 - val_loss: 0.2316 - val_mean_squared_error: 0.2316 - val_mean_absolute_error: 0.4772 - lr: 0.0010
# Epoch 33/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2347 - mean_squared_error: 0.2347 - mean_absolute_error: 0.4791 - val_loss: 0.2311 - val_mean_squared_error: 0.2311 - val_mean_absolute_error: 0.4767 - lr: 0.0010
# Epoch 34/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2312 - mean_squared_error: 0.2312 - mean_absolute_error: 0.4755 - val_loss: 0.2307 - val_mean_squared_error: 0.2307 - val_mean_absolute_error: 0.4761 - lr: 0.0010
# Epoch 35/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2349 - mean_squared_error: 0.2349 - mean_absolute_error: 0.4788 - val_loss: 0.2302 - val_mean_squared_error: 0.2302 - val_mean_absolute_error: 0.4756 - lr: 0.0010
# Epoch 36/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2320 - mean_squared_error: 0.2320 - mean_absolute_error: 0.4759 - val_loss: 0.2298 - val_mean_squared_error: 0.2298 - val_mean_absolute_error: 0.4750 - lr: 0.0010
# Epoch 37/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2301 - mean_squared_error: 0.2301 - mean_absolute_error: 0.4739 - val_loss: 0.2293 - val_mean_squared_error: 0.2293 - val_mean_absolute_error: 0.4744 - lr: 0.0010
# Epoch 38/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2324 - mean_squared_error: 0.2324 - mean_absolute_error: 0.4762 - val_loss: 0.2289 - val_mean_squared_error: 0.2289 - val_mean_absolute_error: 0.4738 - lr: 0.0010
# Epoch 39/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2307 - mean_squared_error: 0.2307 - mean_absolute_error: 0.4746 - val_loss: 0.2285 - val_mean_squared_error: 0.2284 - val_mean_absolute_error: 0.4733 - lr: 0.0010
# Epoch 40/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2318 - mean_squared_error: 0.2318 - mean_absolute_error: 0.4754 - val_loss: 0.2280 - val_mean_squared_error: 0.2280 - val_mean_absolute_error: 0.4727 - lr: 0.0010
# Epoch 41/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2298 - mean_squared_error: 0.2298 - mean_absolute_error: 0.4735 - val_loss: 0.2276 - val_mean_squared_error: 0.2276 - val_mean_absolute_error: 0.4722 - lr: 0.0010
# Epoch 42/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2290 - mean_squared_error: 0.2290 - mean_absolute_error: 0.4724 - val_loss: 0.2271 - val_mean_squared_error: 0.2271 - val_mean_absolute_error: 0.4716 - lr: 0.0010
# Epoch 43/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2278 - mean_squared_error: 0.2278 - mean_absolute_error: 0.4710 - val_loss: 0.2267 - val_mean_squared_error: 0.2267 - val_mean_absolute_error: 0.4710 - lr: 0.0010
# Epoch 44/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2289 - mean_squared_error: 0.2289 - mean_absolute_error: 0.4720 - val_loss: 0.2263 - val_mean_squared_error: 0.2263 - val_mean_absolute_error: 0.4705 - lr: 0.0010
# Epoch 45/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2293 - mean_squared_error: 0.2293 - mean_absolute_error: 0.4723 - val_loss: 0.2258 - val_mean_squared_error: 0.2258 - val_mean_absolute_error: 0.4699 - lr: 0.0010
# Epoch 46/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2280 - mean_squared_error: 0.2280 - mean_absolute_error: 0.4706 - val_loss: 0.2254 - val_mean_squared_error: 0.2254 - val_mean_absolute_error: 0.4693 - lr: 0.0010
# Epoch 47/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2284 - mean_squared_error: 0.2284 - mean_absolute_error: 0.4711 - val_loss: 0.2250 - val_mean_squared_error: 0.2250 - val_mean_absolute_error: 0.4688 - lr: 0.0010
# Epoch 48/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2274 - mean_squared_error: 0.2274 - mean_absolute_error: 0.4698 - val_loss: 0.2246 - val_mean_squared_error: 0.2246 - val_mean_absolute_error: 0.4683 - lr: 0.0010
# Epoch 49/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2262 - mean_squared_error: 0.2262 - mean_absolute_error: 0.4690 - val_loss: 0.2242 - val_mean_squared_error: 0.2241 - val_mean_absolute_error: 0.4677 - lr: 0.0010
# Epoch 50/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2268 - mean_squared_error: 0.2268 - mean_absolute_error: 0.4693 - val_loss: 0.2237 - val_mean_squared_error: 0.2237 - val_mean_absolute_error: 0.4671 - lr: 0.0010
# Epoch 51/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2262 - mean_squared_error: 0.2262 - mean_absolute_error: 0.4684 - val_loss: 0.2233 - val_mean_squared_error: 0.2233 - val_mean_absolute_error: 0.4666 - lr: 0.0010
# Epoch 52/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2254 - mean_squared_error: 0.2253 - mean_absolute_error: 0.4674 - val_loss: 0.2229 - val_mean_squared_error: 0.2229 - val_mean_absolute_error: 0.4660 - lr: 0.0010
# Epoch 53/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2243 - mean_squared_error: 0.2243 - mean_absolute_error: 0.4663 - val_loss: 0.2225 - val_mean_squared_error: 0.2225 - val_mean_absolute_error: 0.4655 - lr: 0.0010
# Epoch 54/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - mean_absolute_error: 0.4681 - val_loss: 0.2221 - val_mean_squared_error: 0.2220 - val_mean_absolute_error: 0.4649 - lr: 0.0010
# Epoch 55/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - mean_absolute_error: 0.4675 - val_loss: 0.2216 - val_mean_squared_error: 0.2216 - val_mean_absolute_error: 0.4643 - lr: 0.0010
# Epoch 56/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2232 - mean_squared_error: 0.2232 - mean_absolute_error: 0.4648 - val_loss: 0.2212 - val_mean_squared_error: 0.2212 - val_mean_absolute_error: 0.4638 - lr: 0.0010
# Epoch 57/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2233 - mean_squared_error: 0.2233 - mean_absolute_error: 0.4648 - val_loss: 0.2208 - val_mean_squared_error: 0.2208 - val_mean_absolute_error: 0.4632 - lr: 0.0010
# Epoch 58/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2229 - mean_squared_error: 0.2229 - mean_absolute_error: 0.4639 - val_loss: 0.2204 - val_mean_squared_error: 0.2204 - val_mean_absolute_error: 0.4627 - lr: 0.0010
# Epoch 59/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2207 - mean_squared_error: 0.2207 - mean_absolute_error: 0.4616 - val_loss: 0.2200 - val_mean_squared_error: 0.2200 - val_mean_absolute_error: 0.4621 - lr: 0.0010
# Epoch 60/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2219 - mean_squared_error: 0.2219 - mean_absolute_error: 0.4629 - val_loss: 0.2196 - val_mean_squared_error: 0.2196 - val_mean_absolute_error: 0.4616 - lr: 0.0010
# Epoch 61/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2214 - mean_squared_error: 0.2214 - mean_absolute_error: 0.4619 - val_loss: 0.2192 - val_mean_squared_error: 0.2192 - val_mean_absolute_error: 0.4611 - lr: 0.0010
# Epoch 62/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - mean_absolute_error: 0.4631 - val_loss: 0.2188 - val_mean_squared_error: 0.2188 - val_mean_absolute_error: 0.4605 - lr: 0.0010
# Epoch 63/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2202 - mean_squared_error: 0.2202 - mean_absolute_error: 0.4608 - val_loss: 0.2184 - val_mean_squared_error: 0.2184 - val_mean_absolute_error: 0.4599 - lr: 0.0010
# Epoch 64/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2196 - mean_squared_error: 0.2195 - mean_absolute_error: 0.4599 - val_loss: 0.2180 - val_mean_squared_error: 0.2180 - val_mean_absolute_error: 0.4594 - lr: 0.0010
# Epoch 65/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - mean_absolute_error: 0.4628 - val_loss: 0.2176 - val_mean_squared_error: 0.2176 - val_mean_absolute_error: 0.4588 - lr: 0.0010
# Epoch 66/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2194 - mean_squared_error: 0.2194 - mean_absolute_error: 0.4593 - val_loss: 0.2172 - val_mean_squared_error: 0.2172 - val_mean_absolute_error: 0.4583 - lr: 0.0010
# Epoch 67/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2181 - mean_squared_error: 0.2180 - mean_absolute_error: 0.4581 - val_loss: 0.2168 - val_mean_squared_error: 0.2168 - val_mean_absolute_error: 0.4577 - lr: 0.0010
# Epoch 68/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2182 - mean_squared_error: 0.2182 - mean_absolute_error: 0.4579 - val_loss: 0.2164 - val_mean_squared_error: 0.2164 - val_mean_absolute_error: 0.4572 - lr: 0.0010
# Epoch 69/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2176 - mean_squared_error: 0.2176 - mean_absolute_error: 0.4570 - val_loss: 0.2160 - val_mean_squared_error: 0.2159 - val_mean_absolute_error: 0.4566 - lr: 0.0010
# Epoch 70/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2175 - mean_squared_error: 0.2175 - mean_absolute_error: 0.4566 - val_loss: 0.2156 - val_mean_squared_error: 0.2155 - val_mean_absolute_error: 0.4561 - lr: 0.0010
# Epoch 71/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2189 - mean_squared_error: 0.2189 - mean_absolute_error: 0.4579 - val_loss: 0.2152 - val_mean_squared_error: 0.2151 - val_mean_absolute_error: 0.4555 - lr: 0.0010
# Epoch 72/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2170 - mean_squared_error: 0.2170 - mean_absolute_error: 0.4560 - val_loss: 0.2148 - val_mean_squared_error: 0.2147 - val_mean_absolute_error: 0.4549 - lr: 0.0010
# Epoch 73/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2178 - mean_squared_error: 0.2177 - mean_absolute_error: 0.4567 - val_loss: 0.2144 - val_mean_squared_error: 0.2143 - val_mean_absolute_error: 0.4544 - lr: 0.0010
# Epoch 74/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2171 - mean_squared_error: 0.2171 - mean_absolute_error: 0.4561 - val_loss: 0.2140 - val_mean_squared_error: 0.2139 - val_mean_absolute_error: 0.4538 - lr: 0.0010
# Epoch 75/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2169 - mean_squared_error: 0.2168 - mean_absolute_error: 0.4555 - val_loss: 0.2136 - val_mean_squared_error: 0.2135 - val_mean_absolute_error: 0.4532 - lr: 0.0010
# Epoch 76/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2163 - mean_squared_error: 0.2163 - mean_absolute_error: 0.4549 - val_loss: 0.2132 - val_mean_squared_error: 0.2131 - val_mean_absolute_error: 0.4527 - lr: 0.0010
# Epoch 77/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2147 - mean_squared_error: 0.2147 - mean_absolute_error: 0.4530 - val_loss: 0.2128 - val_mean_squared_error: 0.2127 - val_mean_absolute_error: 0.4521 - lr: 0.0010
# Epoch 78/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2143 - mean_squared_error: 0.2142 - mean_absolute_error: 0.4519 - val_loss: 0.2124 - val_mean_squared_error: 0.2123 - val_mean_absolute_error: 0.4516 - lr: 0.0010
# Epoch 79/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2164 - mean_squared_error: 0.2163 - mean_absolute_error: 0.4547 - val_loss: 0.2120 - val_mean_squared_error: 0.2119 - val_mean_absolute_error: 0.4510 - lr: 0.0010
# Epoch 80/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2140 - mean_squared_error: 0.2139 - mean_absolute_error: 0.4520 - val_loss: 0.2116 - val_mean_squared_error: 0.2115 - val_mean_absolute_error: 0.4505 - lr: 0.0010
# Epoch 81/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2146 - mean_squared_error: 0.2146 - mean_absolute_error: 0.4523 - val_loss: 0.2112 - val_mean_squared_error: 0.2111 - val_mean_absolute_error: 0.4499 - lr: 0.0010
# Epoch 82/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2128 - mean_squared_error: 0.2128 - mean_absolute_error: 0.4504 - val_loss: 0.2108 - val_mean_squared_error: 0.2107 - val_mean_absolute_error: 0.4493 - lr: 0.0010
# Epoch 83/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2117 - mean_squared_error: 0.2117 - mean_absolute_error: 0.4488 - val_loss: 0.2104 - val_mean_squared_error: 0.2103 - val_mean_absolute_error: 0.4487 - lr: 0.0010
# Epoch 84/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2113 - mean_squared_error: 0.2112 - mean_absolute_error: 0.4486 - val_loss: 0.2100 - val_mean_squared_error: 0.2099 - val_mean_absolute_error: 0.4482 - lr: 0.0010
# Epoch 85/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2118 - mean_squared_error: 0.2118 - mean_absolute_error: 0.4488 - val_loss: 0.2096 - val_mean_squared_error: 0.2095 - val_mean_absolute_error: 0.4476 - lr: 0.0010
# Epoch 86/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2121 - mean_squared_error: 0.2120 - mean_absolute_error: 0.4490 - val_loss: 0.2092 - val_mean_squared_error: 0.2092 - val_mean_absolute_error: 0.4470 - lr: 0.0010
# Epoch 87/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2121 - mean_squared_error: 0.2121 - mean_absolute_error: 0.4489 - val_loss: 0.2088 - val_mean_squared_error: 0.2088 - val_mean_absolute_error: 0.4464 - lr: 0.0010
# Epoch 88/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2110 - mean_squared_error: 0.2110 - mean_absolute_error: 0.4472 - val_loss: 0.2084 - val_mean_squared_error: 0.2084 - val_mean_absolute_error: 0.4459 - lr: 0.0010
# Epoch 89/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2102 - mean_squared_error: 0.2101 - mean_absolute_error: 0.4462 - val_loss: 0.2080 - val_mean_squared_error: 0.2080 - val_mean_absolute_error: 0.4453 - lr: 0.0010
# Epoch 90/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2093 - mean_squared_error: 0.2092 - mean_absolute_error: 0.4452 - val_loss: 0.2076 - val_mean_squared_error: 0.2076 - val_mean_absolute_error: 0.4447 - lr: 0.0010
# Epoch 91/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2108 - mean_squared_error: 0.2108 - mean_absolute_error: 0.4466 - val_loss: 0.2072 - val_mean_squared_error: 0.2072 - val_mean_absolute_error: 0.4441 - lr: 0.0010
# Epoch 92/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2106 - mean_squared_error: 0.2106 - mean_absolute_error: 0.4468 - val_loss: 0.2068 - val_mean_squared_error: 0.2068 - val_mean_absolute_error: 0.4436 - lr: 0.0010
# Epoch 93/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2098 - mean_squared_error: 0.2097 - mean_absolute_error: 0.4454 - val_loss: 0.2064 - val_mean_squared_error: 0.2064 - val_mean_absolute_error: 0.4430 - lr: 0.0010
# Epoch 94/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2081 - mean_squared_error: 0.2081 - mean_absolute_error: 0.4433 - val_loss: 0.2061 - val_mean_squared_error: 0.2060 - val_mean_absolute_error: 0.4424 - lr: 0.0010
# Epoch 95/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2086 - mean_squared_error: 0.2086 - mean_absolute_error: 0.4441 - val_loss: 0.2057 - val_mean_squared_error: 0.2056 - val_mean_absolute_error: 0.4419 - lr: 0.0010
# Epoch 96/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2082 - mean_squared_error: 0.2082 - mean_absolute_error: 0.4428 - val_loss: 0.2053 - val_mean_squared_error: 0.2052 - val_mean_absolute_error: 0.4413 - lr: 0.0010
# Epoch 97/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2067 - mean_squared_error: 0.2066 - mean_absolute_error: 0.4413 - val_loss: 0.2049 - val_mean_squared_error: 0.2048 - val_mean_absolute_error: 0.4407 - lr: 0.0010
# Epoch 98/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.2073 - mean_squared_error: 0.2072 - mean_absolute_error: 0.4419 - val_loss: 0.2045 - val_mean_squared_error: 0.2045 - val_mean_absolute_error: 0.4401 - lr: 0.0010
# Epoch 99/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2074 - mean_squared_error: 0.2073 - mean_absolute_error: 0.4417 - val_loss: 0.2041 - val_mean_squared_error: 0.2041 - val_mean_absolute_error: 0.4396 - lr: 0.0010
# Epoch 100/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.2066 - mean_squared_error: 0.2066 - mean_absolute_error: 0.4401 - val_loss: 0.2038 - val_mean_squared_error: 0.2037 - val_mean_absolute_error: 0.4390 - lr: 0.0010
# Number of epochs run: 100
# Evaluating model performance on test set...
#
# ============ Scores ============
# loss                : 1.9729e-01
# mean_squared_error  : 1.9724e-01
# mean_absolute_error : 4.3060e-01
#
#
# Test loss: 0.19729189574718475

# %%
print(np.shape(unlab_pcs))
pred_labels = model.predict(unlab_pcs)
print(np.shape(pred_labels))

#red => 0 => functional_false; green => 1 => functional_true
colors = ['red','green']
groups = ['functional_false', 'functional_true']

fig = plt.figure(figsize=(8,8))
plt.scatter(unlab_pcs[:,0], unlab_pcs[:,1], c=pred_labels, marker = '+', label=groups,
            cmap=matplotlib.colors.ListedColormap(colors))
plt.xlabel('Principal Component - 1')
plt.ylabel('Principal Component - 2')
#plt.legend(loc=2)
plt.title("Principal Components of data labeled with DNN")

print("However, we know that this has a fail rate of at least 25%")

print("There's an estimated " + str(int(np.sum(pred_labels)*100/6269)) + " % functional sequences")
# Out:
# (6269, 500)
# (6269, 1)
# However, we know that this has a fail rate of at least 25%
# There's an estimated 43 % functional sequences

# %% [markdown]
# As expected, this does not yield very good results: we have too few data (2133 units of dimension 500!)
# But it was fun coding a NN, and it's good practice. Hoxever, fun is good, so we should use a better suited method: let's use random forest
# (What follows relies heavily on the asociated Jupyter notebook)

# %%
#Apply Random Forest
#This is the random forest classifier
from sklearn.ensemble import RandomForestClassifier
#This is the extreme randomized trees
from sklearn.ensemble import ExtraTreesClassifier
#import time to see how perforamance depends on run time
import time
import warnings
#Comment to turn on warnings
warnings.filterwarnings("ignore")

input_data = all_lab_data
output_data = all_lab

# Steps to shuffle:
joined_lists = list(zip(input_data, output_data))
random.shuffle(joined_lists) # Shuffle "joined_lists" in place
input_data, output_data = zip(*joined_lists) # Undo joining
input_data = np.array(input_data)
output_data = np.array(output_data)
print(np.shape(input_data))

#Def fraction train/test/validation
fraction_train = 0.8
stop_1 = int(fraction_train*len(output_data))

X_train, Y_train = input_data[:stop_1], output_data[:stop_1]
X_test, Y_test = input_data[stop_1+1:], output_data[stop_1+1:]

#We will check 

min_estimators = 10
max_estimators = 101
classifer = RandomForestClassifier # BELOW WE WILL CHANGE for the case of extremly randomized forest 

n_estimator_range=np.arange(min_estimators, max_estimators, 10)
leaf_size_list=[2,3, 4, 5, 6, 7, 8]

m=len(n_estimator_range)
n=len(leaf_size_list)

#Allocate Arrays for various quantities

RFC_OOB_accuracy=np.zeros((n,m))
RFC_train_accuracy=np.zeros((n,m))
RFC_test_accuracy=np.zeros((n,m))
run_time=np.zeros((n,m))

print_flag=True

for i, leaf_size in enumerate(leaf_size_list):
    # Define Random Forest Classifier
    myRF_clf = classifer(
        n_estimators=min_estimators,
        max_depth=None, 
        min_samples_split=leaf_size, # minimum number of sample per leaf
        oob_score=True,
        random_state=0,
        warm_start=True # this ensures that you add estimators without retraining everything
    )
    for j, n_estimator in enumerate(n_estimator_range):
        
        print('n_estimators: %i, leaf_size: %i'%(n_estimator,leaf_size))
        
        start_time = time.time()
        myRF_clf.set_params(n_estimators=n_estimator)
        myRF_clf.fit(X_train, Y_train)
        run_time[i,j] = time.time() - start_time

    # check accuracy
        RFC_train_accuracy[i,j]=myRF_clf.score(X_train,Y_train)
        RFC_OOB_accuracy[i,j]=myRF_clf.oob_score_
        RFC_test_accuracy[i,j]=myRF_clf.score(X_test,Y_test)
        if print_flag:
            result = (run_time[i,j], RFC_train_accuracy[i,j], RFC_OOB_accuracy[i,j], RFC_test_accuracy[i,j])
            print('{0:<15}{1:<15}{2:<15}{3:<15}'.format("time (s)","train score", "OOB estimate","test score"))
            print('{0:<15.4f}{1:<15.4f}{2:<15.4f}{3:<15.4f}'.format(*result))
# Out:
# (2133, 1920)
# n_estimators: 10, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.0958         0.9877         0.7433         0.7911
# n_estimators: 20, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.1042         0.9982         0.7679         0.8146
# n_estimators: 30, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.1310         0.9988         0.7814         0.8028
# n_estimators: 40, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.1442         1.0000         0.7819         0.8192
# n_estimators: 50, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.1517         1.0000         0.7878         0.8099
# n_estimators: 60, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.1729         1.0000         0.7978         0.8075
# n_estimators: 70, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.1958         1.0000         0.7960         0.8052
# n_estimators: 80, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.2142         1.0000         0.7948         0.8075
# n_estimators: 90, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.2369         1.0000         0.7972         0.8122
# n_estimators: 100, leaf_size: 2
# time (s)       train score    OOB estimate   test score
# 0.2482         1.0000         0.7966         0.8146
# n_estimators: 10, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.0836         0.9807         0.7374         0.7770
# n_estimators: 20, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.0971         0.9918         0.7644         0.7793
# n_estimators: 30, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.1128         0.9947         0.7737         0.7864
# n_estimators: 40, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.1234         0.9953         0.7819         0.7840
# n_estimators: 50, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.1185         0.9965         0.7796         0.7864
# n_estimators: 60, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.1376         0.9977         0.7849         0.7864
# n_estimators: 70, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.1368         0.9977         0.7884         0.7887
# n_estimators: 80, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.1523         0.9977         0.7925         0.7911
# n_estimators: 90, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.1845         0.9971         0.7919         0.7817
# n_estimators: 100, leaf_size: 3
# time (s)       train score    OOB estimate   test score
# 0.1980         0.9977         0.7960         0.7887
# n_estimators: 10, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.0803         0.9672         0.7433         0.7817
# n_estimators: 20, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.0821         0.9848         0.7638         0.7840
# n_estimators: 30, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.0975         0.9859         0.7819         0.7887
# n_estimators: 40, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.1025         0.9906         0.7855         0.7723
# n_estimators: 50, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.1192         0.9889         0.7913         0.7864
# n_estimators: 60, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.1317         0.9894         0.7761         0.7911
# n_estimators: 70, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.1442         0.9900         0.7837         0.7958
# n_estimators: 80, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.1695         0.9894         0.7849         0.7840
# n_estimators: 90, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.1607         0.9894         0.7884         0.7958
# n_estimators: 100, leaf_size: 4
# time (s)       train score    OOB estimate   test score
# 0.1670         0.9889         0.7937         0.7887
# n_estimators: 10, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.0770         0.9601         0.7491         0.7887
# n_estimators: 20, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.0805         0.9719         0.7544         0.8005
# n_estimators: 30, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.0971         0.9760         0.7743         0.8028
# n_estimators: 40, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.1019         0.9795         0.7761         0.8169
# n_estimators: 50, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.1236         0.9824         0.7860         0.8169
# n_estimators: 60, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.1305         0.9830         0.7907         0.8122
# n_estimators: 70, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.1459         0.9848         0.7960         0.7981
# n_estimators: 80, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.1682         0.9818         0.7978         0.8005
# n_estimators: 90, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.1687         0.9812         0.7960         0.8028
# n_estimators: 100, leaf_size: 5
# time (s)       train score    OOB estimate   test score
# 0.1710         0.9818         0.7943         0.8075
# n_estimators: 10, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.0879         0.9461         0.7521         0.7887
# n_estimators: 20, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.0952         0.9666         0.7802         0.7911
# n_estimators: 30, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.0999         0.9754         0.7773         0.8146
# n_estimators: 40, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.1043         0.9766         0.7860         0.8052
# n_estimators: 50, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.1302         0.9760         0.7919         0.8052
# n_estimators: 60, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.1465         0.9789         0.7907         0.8146
# n_estimators: 70, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.1384         0.9760         0.7943         0.8169
# n_estimators: 80, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.1497         0.9777         0.7937         0.8122
# n_estimators: 90, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.1663         0.9760         0.7931         0.8122
# n_estimators: 100, leaf_size: 6
# time (s)       train score    OOB estimate   test score
# 0.1855         0.9766         0.7954         0.8169
# n_estimators: 10, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.0849         0.9443         0.7526         0.7700
# n_estimators: 20, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.0964         0.9607         0.7755         0.7934
# n_estimators: 30, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.1017         0.9672         0.7902         0.7887
# n_estimators: 40, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.1217         0.9672         0.7878         0.7981
# n_estimators: 50, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.1275         0.9701         0.7872         0.7981
# n_estimators: 60, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.1424         0.9719         0.7913         0.7981
# n_estimators: 70, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.1545         0.9707         0.7937         0.7934
# n_estimators: 80, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.1664         0.9725         0.7937         0.7958
# n_estimators: 90, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.1897         0.9725         0.7978         0.7958
# n_estimators: 100, leaf_size: 7
# time (s)       train score    OOB estimate   test score
# 0.1774         0.9730         0.7978         0.7981
# n_estimators: 10, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.0841         0.9396         0.7562         0.8028
# n_estimators: 20, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.0917         0.9578         0.7702         0.8122
# n_estimators: 30, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.1039         0.9631         0.7773         0.8169
# n_estimators: 40, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.1078         0.9648         0.7872         0.8146
# n_estimators: 50, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.1264         0.9654         0.7931         0.8169
# n_estimators: 60, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.1575         0.9648         0.7943         0.8146
# n_estimators: 70, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.1615         0.9642         0.7913         0.8052
# n_estimators: 80, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.1642         0.9642         0.7913         0.8122
# n_estimators: 90, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.1615         0.9660         0.7954         0.8146
# n_estimators: 100, leaf_size: 8
# time (s)       train score    OOB estimate   test score
# 0.1887         0.9648         0.7948         0.8122

# %%
plt.figure(figsize=(10,10))
color = plt.cm.viridis(np.linspace(0, 1, len(leaf_size_list)))
for i, leaves in enumerate(leaf_size_list) :
    plt.plot()
    plt.plot(n_estimator_range,RFC_train_accuracy[i],'--', c=color[i], label='Train '+str(leaves))
    plt.plot(n_estimator_range,RFC_test_accuracy[i], c=color[i], label='Test '+str(leaves))
    plt.legend()
plt.show()

# %%
myRF_clf = classifer(
    n_estimators=min_estimators,
    max_depth=None, 
    min_samples_split=7, # minimum number of sample per leaf
    oob_score=True,
    random_state=0,
    warm_start=True # this ensures that you add estimators without retraining everything
)

myRF_clf.set_params(n_estimators=35)
myRF_clf.fit(X_train, Y_train)

predictions = myRF_clf.predict(np.array(encoded_data_unlab))
#functionality = [1 if predictions[0]==0 else 0 for prediction in predictions]

# %%
pcs_pred = apply_PCA(encoded_data_unlab)
visualize_pcs(pcs_pred, predictions, "Labelling with Random Forest model")

print("There's an estimated " + str(int(np.sum(predictions)*100/6269)) + " % functional sequences")
# Out:
# With 512 components, we keep 95% of the variance!
# With the first 2 components, we only keep 7.638790852685834% of the variance
# There's an estimated 40 % functional sequences
